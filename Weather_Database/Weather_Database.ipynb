# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 744

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | katsuura
# Processing Record 2 of Set 1 | burnie
# Processing Record 3 of Set 1 | mersing
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 6 of Set 1 | la orilla
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | puerto carreno
# Processing Record 9 of Set 1 | caravelas
# Processing Record 10 of Set 1 | nanortalik
# Processing Record 11 of Set 1 | kresttsy
# Processing Record 12 of Set 1 | constitucion
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | kahului
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | poum
# Processing Record 21 of Set 1 | galveston
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping
# Processing Record 23 of Set 1 | mao
# Processing Record 24 of Set 1 | maragogi
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | attawapiskat
# City not found. Skipping
# Processing Record 27 of Set 1 | valdivia
# Processing Record 28 of Set 1 | ulaangom
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | carutapera
# Processing Record 32 of Set 1 | codrington
# Processing Record 33 of Set 1 | vaitupu
# City not found. Skipping
# Processing Record 34 of Set 1 | waitati
# Processing Record 35 of Set 1 | tumannyy
# City not found. Skipping
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | tual
# Processing Record 39 of Set 1 | lompoc
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | egvekinot
# Processing Record 42 of Set 1 | talgar
# Processing Record 43 of Set 1 | thinadhoo
# Processing Record 44 of Set 1 | yulara
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | muscat
# Processing Record 47 of Set 1 | monte santo de minas
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | atar
# Processing Record 50 of Set 1 | pionerskiy
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | alofi
# Processing Record 3 of Set 2 | chuy
# Processing Record 4 of Set 2 | shouguang
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | vao
# Processing Record 7 of Set 2 | skeldon
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping
# Processing Record 9 of Set 2 | hambantota
# Processing Record 10 of Set 2 | kropotkin
# Processing Record 11 of Set 2 | butia
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | port macquarie
# Processing Record 14 of Set 2 | faanui
# Processing Record 15 of Set 2 | saleaula
# City not found. Skipping
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | belyy yar
# Processing Record 18 of Set 2 | manaus
# Processing Record 19 of Set 2 | los llanos de aridane
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | coihaique
# Processing Record 22 of Set 2 | kuche
# City not found. Skipping
# Processing Record 23 of Set 2 | upernavik
# Processing Record 24 of Set 2 | ndjole
# Processing Record 25 of Set 2 | tupik
# Processing Record 26 of Set 2 | moranbah
# Processing Record 27 of Set 2 | ushuaia
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | kidal
# Processing Record 30 of Set 2 | hermanus
# Processing Record 31 of Set 2 | praia da vitoria
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | shimoda
# Processing Record 35 of Set 2 | palmer
# Processing Record 36 of Set 2 | lavrentiya
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | kastamonu
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | launceston
# Processing Record 43 of Set 2 | grindavik
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | nizhneyansk
# City not found. Skipping
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | ancud
# Processing Record 49 of Set 2 | flinders
# Processing Record 50 of Set 2 | ulladulla
# Processing Record 1 of Set 3 | tigil
# Processing Record 2 of Set 3 | port hedland
# Processing Record 3 of Set 3 | banjarmasin
# Processing Record 4 of Set 3 | ponta delgada
# Processing Record 5 of Set 3 | guaira
# Processing Record 6 of Set 3 | mehran
# Processing Record 7 of Set 3 | marietta
# Processing Record 8 of Set 3 | gouyave
# Processing Record 9 of Set 3 | ngunguru
# Processing Record 10 of Set 3 | nome
# Processing Record 11 of Set 3 | samusu
# City not found. Skipping
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | kholodnyy
# Processing Record 14 of Set 3 | norman wells
# Processing Record 15 of Set 3 | raga
# Processing Record 16 of Set 3 | brownwood
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | bereda
# Processing Record 20 of Set 3 | grootfontein
# Processing Record 21 of Set 3 | mount isa
# Processing Record 22 of Set 3 | atuona
# Processing Record 23 of Set 3 | juneau
# Processing Record 24 of Set 3 | pa daet
# Processing Record 25 of Set 3 | grand gaube
# Processing Record 26 of Set 3 | mpulungu
# Processing Record 27 of Set 3 | qasigiannguit
# Processing Record 28 of Set 3 | komsomolskiy
# Processing Record 29 of Set 3 | tessalit
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | murray bridge
# Processing Record 33 of Set 3 | tainan
# Processing Record 34 of Set 3 | lephepe
# City not found. Skipping
# Processing Record 35 of Set 3 | hiranagar
# Processing Record 36 of Set 3 | plettenberg bay
# Processing Record 37 of Set 3 | kawardha
# Processing Record 38 of Set 3 | hamilton
# Processing Record 39 of Set 3 | udalguri
# Processing Record 40 of Set 3 | hithadhoo
# Processing Record 41 of Set 3 | cabo san lucas
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | port loko
# Processing Record 44 of Set 3 | tra vinh
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | samarkand
# Processing Record 47 of Set 3 | tasiilaq
# Processing Record 48 of Set 3 | mizque
# Processing Record 49 of Set 3 | santarem
# Processing Record 50 of Set 3 | hobart
# Processing Record 1 of Set 4 | shaghat
# Processing Record 2 of Set 4 | talnakh
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | satitoa
# City not found. Skipping
# Processing Record 5 of Set 4 | devonport
# Processing Record 6 of Set 4 | narsaq
# Processing Record 7 of Set 4 | lobito
# Processing Record 8 of Set 4 | palabuhanratu
# City not found. Skipping
# Processing Record 9 of Set 4 | umzimvubu
# City not found. Skipping
# Processing Record 10 of Set 4 | sisimiut
# Processing Record 11 of Set 4 | tucurui
# Processing Record 12 of Set 4 | posadas
# Processing Record 13 of Set 4 | samarai
# Processing Record 14 of Set 4 | prince rupert
# Processing Record 15 of Set 4 | lebedinyy
# Processing Record 16 of Set 4 | san quintin
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | waingapu
# Processing Record 19 of Set 4 | sambava
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | mehamn
# Processing Record 22 of Set 4 | pokosnoye
# Processing Record 23 of Set 4 | mar del plata
# Processing Record 24 of Set 4 | gambela
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | shatrovo
# Processing Record 28 of Set 4 | avera
# Processing Record 29 of Set 4 | oranjemund
# Processing Record 30 of Set 4 | artyk
# City not found. Skipping
# Processing Record 31 of Set 4 | svetlyy
# Processing Record 32 of Set 4 | tandalti
# Processing Record 33 of Set 4 | sao filipe
# Processing Record 34 of Set 4 | middle island
# Processing Record 35 of Set 4 | dingle
# Processing Record 36 of Set 4 | haines junction
# Processing Record 37 of Set 4 | general roca
# Processing Record 38 of Set 4 | dandong
# Processing Record 39 of Set 4 | iberia
# Processing Record 40 of Set 4 | kodiak
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | uklana mandi
# Processing Record 43 of Set 4 | victoria
# Processing Record 44 of Set 4 | toamasina
# Processing Record 45 of Set 4 | marsh harbour
# Processing Record 46 of Set 4 | beipiao
# Processing Record 47 of Set 4 | fredericton
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | son la
# Processing Record 50 of Set 4 | ambrolauri
# Processing Record 1 of Set 5 | kushiro
# Processing Record 2 of Set 5 | peachland
# Processing Record 3 of Set 5 | tsihombe
# City not found. Skipping
# Processing Record 4 of Set 5 | banyo
# Processing Record 5 of Set 5 | asyut
# Processing Record 6 of Set 5 | dunedin
# Processing Record 7 of Set 5 | dasoguz
# Processing Record 8 of Set 5 | shache
# Processing Record 9 of Set 5 | moron
# Processing Record 10 of Set 5 | monte alegre
# Processing Record 11 of Set 5 | faya
# Processing Record 12 of Set 5 | araouane
# Processing Record 13 of Set 5 | saint-francois
# Processing Record 14 of Set 5 | chara
# Processing Record 15 of Set 5 | kaitong
# Processing Record 16 of Set 5 | sao felix do xingu
# Processing Record 17 of Set 5 | iquitos
# Processing Record 18 of Set 5 | saint-georges
# Processing Record 19 of Set 5 | mahbubabad
# Processing Record 20 of Set 5 | rio grande
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | tabiauea
# City not found. Skipping
# Processing Record 23 of Set 5 | cambridge
# Processing Record 24 of Set 5 | jiangkou
# Processing Record 25 of Set 5 | puquio
# Processing Record 26 of Set 5 | nikolskoye
# Processing Record 27 of Set 5 | geraldton
# Processing Record 28 of Set 5 | priargunsk
# Processing Record 29 of Set 5 | makokou
# Processing Record 30 of Set 5 | bud
# Processing Record 31 of Set 5 | bambous virieux
# Processing Record 32 of Set 5 | sentyabrskiy
# City not found. Skipping
# Processing Record 33 of Set 5 | bathsheba
# Processing Record 34 of Set 5 | ribeira grande
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | auki
# Processing Record 37 of Set 5 | buin
# Processing Record 38 of Set 5 | nguiu
# City not found. Skipping
# Processing Record 39 of Set 5 | vanimo
# Processing Record 40 of Set 5 | huanren
# Processing Record 41 of Set 5 | huarmey
# Processing Record 42 of Set 5 | isangel
# Processing Record 43 of Set 5 | meulaboh
# Processing Record 44 of Set 5 | karaul
# City not found. Skipping
# Processing Record 45 of Set 5 | bidor
# Processing Record 46 of Set 5 | rupert
# Processing Record 47 of Set 5 | hualmay
# Processing Record 48 of Set 5 | semirom
# Processing Record 49 of Set 5 | port keats
# Processing Record 50 of Set 5 | itarema
# Processing Record 1 of Set 6 | parrita
# Processing Record 2 of Set 6 | kayasula
# Processing Record 3 of Set 6 | yar-sale
# Processing Record 4 of Set 6 | amsterdam
# Processing Record 5 of Set 6 | sechura
# Processing Record 6 of Set 6 | pinawa
# Processing Record 7 of Set 6 | puksoozero
# Processing Record 8 of Set 6 | gimli
# Processing Record 9 of Set 6 | baykit
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | new norfolk
# Processing Record 12 of Set 6 | novaya bryan
# Processing Record 13 of Set 6 | mitsamiouli
# Processing Record 14 of Set 6 | el paso
# Processing Record 15 of Set 6 | olinda
# Processing Record 16 of Set 6 | saint george
# Processing Record 17 of Set 6 | pustoshka
# Processing Record 18 of Set 6 | aripuana
# Processing Record 19 of Set 6 | naral
# City not found. Skipping
# Processing Record 20 of Set 6 | lamesa
# Processing Record 21 of Set 6 | sam roi yot
# Processing Record 22 of Set 6 | vardo
# Processing Record 23 of Set 6 | chapais
# Processing Record 24 of Set 6 | wattegama
# Processing Record 25 of Set 6 | lahad datu
# Processing Record 26 of Set 6 | leningradskiy
# Processing Record 27 of Set 6 | bethel
# Processing Record 28 of Set 6 | cayenne
# Processing Record 29 of Set 6 | basco
# Processing Record 30 of Set 6 | nara
# Processing Record 31 of Set 6 | zhenlai
# Processing Record 32 of Set 6 | casablanca
# Processing Record 33 of Set 6 | juifang
# City not found. Skipping
# Processing Record 34 of Set 6 | aitape
# Processing Record 35 of Set 6 | kruisfontein
# Processing Record 36 of Set 6 | kulu
# Processing Record 37 of Set 6 | severo-kurilsk
# Processing Record 38 of Set 6 | sao joao da barra
# Processing Record 39 of Set 6 | qingan
# City not found. Skipping
# Processing Record 40 of Set 6 | banepa
# Processing Record 41 of Set 6 | sao mateus do maranhao
# Processing Record 42 of Set 6 | namwala
# Processing Record 43 of Set 6 | copiapo
# Processing Record 44 of Set 6 | agadez
# Processing Record 45 of Set 6 | belushya guba
# City not found. Skipping
# Processing Record 46 of Set 6 | saint-joseph
# Processing Record 47 of Set 6 | mezhova
# Processing Record 48 of Set 6 | sayaxche
# Processing Record 49 of Set 6 | carballo
# Processing Record 50 of Set 6 | tamale
# Processing Record 1 of Set 7 | amazar
# Processing Record 2 of Set 7 | novikovo
# Processing Record 3 of Set 7 | amderma
# City not found. Skipping
# Processing Record 4 of Set 7 | pisco
# Processing Record 5 of Set 7 | bilibino
# Processing Record 6 of Set 7 | tolstoy-yurt
# Processing Record 7 of Set 7 | belmonte
# Processing Record 8 of Set 7 | ostrovnoy
# Processing Record 9 of Set 7 | lazaro cardenas
# Processing Record 10 of Set 7 | rawson
# Processing Record 11 of Set 7 | ketchenery
# City not found. Skipping
# Processing Record 12 of Set 7 | marrakesh
# Processing Record 13 of Set 7 | clonakilty
# Processing Record 14 of Set 7 | milyutinskaya
# Processing Record 15 of Set 7 | manokwari
# Processing Record 16 of Set 7 | virginia beach
# Processing Record 17 of Set 7 | maraba
# Processing Record 18 of Set 7 | batemans bay
# Processing Record 19 of Set 7 | longlac
# City not found. Skipping
# Processing Record 20 of Set 7 | slave lake
# Processing Record 21 of Set 7 | kimbe
# Processing Record 22 of Set 7 | lorengau
# Processing Record 23 of Set 7 | udachnyy
# Processing Record 24 of Set 7 | mahebourg
# Processing Record 25 of Set 7 | east london
# Processing Record 26 of Set 7 | litovko
# Processing Record 27 of Set 7 | guajara
# Processing Record 28 of Set 7 | kurumkan
# Processing Record 29 of Set 7 | jinchang
# Processing Record 30 of Set 7 | rio grande city
# Processing Record 31 of Set 7 | trstena
# Processing Record 32 of Set 7 | muros
# Processing Record 33 of Set 7 | eydhafushi
# Processing Record 34 of Set 7 | tabou
# Processing Record 35 of Set 7 | red bluff
# Processing Record 36 of Set 7 | ust-kuyga
# Processing Record 37 of Set 7 | outlook
# Processing Record 38 of Set 7 | gaoyou
# Processing Record 39 of Set 7 | lasa
# Processing Record 40 of Set 7 | barao de melgaco
# Processing Record 41 of Set 7 | sal rei
# Processing Record 42 of Set 7 | mahon
# Processing Record 43 of Set 7 | hovd
# Processing Record 44 of Set 7 | dunkirk
# Processing Record 45 of Set 7 | antalaha
# Processing Record 46 of Set 7 | sabang
# Processing Record 47 of Set 7 | mahanje
# Processing Record 48 of Set 7 | ilheus
# Processing Record 49 of Set 7 | aykhal
# Processing Record 50 of Set 7 | derbent
# Processing Record 1 of Set 8 | serik
# Processing Record 2 of Set 8 | souillac
# Processing Record 3 of Set 8 | tuatapere
# Processing Record 4 of Set 8 | mullaitivu
# City not found. Skipping
# Processing Record 5 of Set 8 | rexburg
# Processing Record 6 of Set 8 | saint-augustin
# Processing Record 7 of Set 8 | lubango
# Processing Record 8 of Set 8 | allapalli
# Processing Record 9 of Set 8 | thunder bay
# Processing Record 10 of Set 8 | boromo
# Processing Record 11 of Set 8 | tura
# Processing Record 12 of Set 8 | susehri
# Processing Record 13 of Set 8 | srednekolymsk
# Processing Record 14 of Set 8 | peniche
# Processing Record 15 of Set 8 | tateyama
# Processing Record 16 of Set 8 | najran
# Processing Record 17 of Set 8 | vazante
# Processing Record 18 of Set 8 | pundaguitan
# Processing Record 19 of Set 8 | along
# Processing Record 20 of Set 8 | ichinohe
# Processing Record 21 of Set 8 | surt
# Processing Record 22 of Set 8 | cabedelo
# Processing Record 23 of Set 8 | toora-khem
# Processing Record 24 of Set 8 | port-gentil
# Processing Record 25 of Set 8 | maniitsoq
# Processing Record 26 of Set 8 | pocoes
# Processing Record 27 of Set 8 | paita
# Processing Record 28 of Set 8 | usinsk
# Processing Record 29 of Set 8 | the valley
# Processing Record 30 of Set 8 | kamenskoye
# City not found. Skipping
# Processing Record 31 of Set 8 | yumen
# Processing Record 32 of Set 8 | tapaua
# City not found. Skipping
# Processing Record 33 of Set 8 | road town
# Processing Record 34 of Set 8 | ramnagar
# Processing Record 35 of Set 8 | kaduqli
# Processing Record 36 of Set 8 | kutum
# Processing Record 37 of Set 8 | morondava
# Processing Record 38 of Set 8 | san benito
# Processing Record 39 of Set 8 | itoman
# Processing Record 40 of Set 8 | zhezkazgan
# Processing Record 41 of Set 8 | freeport
# Processing Record 42 of Set 8 | cherskiy
# Processing Record 43 of Set 8 | sao miguel do araguaia
# Processing Record 44 of Set 8 | dekar
# Processing Record 45 of Set 8 | kavieng
# Processing Record 46 of Set 8 | zhicheng
# Processing Record 47 of Set 8 | port hardy
# Processing Record 48 of Set 8 | alice springs
# Processing Record 49 of Set 8 | salym
# Processing Record 50 of Set 8 | nyurba
# Processing Record 1 of Set 9 | mandera
# Processing Record 2 of Set 9 | eucaliptus
# Processing Record 3 of Set 9 | jiwani
# Processing Record 4 of Set 9 | erzin
# Processing Record 5 of Set 9 | jequitinhonha
# Processing Record 6 of Set 9 | presidencia roque saenz pena
# Processing Record 7 of Set 9 | rocha
# Processing Record 8 of Set 9 | lichinga
# Processing Record 9 of Set 9 | tarhunah
# City not found. Skipping
# Processing Record 10 of Set 9 | makakilo city
# Processing Record 11 of Set 9 | monterey
# Processing Record 12 of Set 9 | saint anthony
# Processing Record 13 of Set 9 | pativilca
# Processing Record 14 of Set 9 | karakol
# Processing Record 15 of Set 9 | tauranga
# Processing Record 16 of Set 9 | namatanai
# Processing Record 17 of Set 9 | shubarshi
# Processing Record 18 of Set 9 | dehloran
# Processing Record 19 of Set 9 | oskemen
# Processing Record 20 of Set 9 | mbuji-mayi
# Processing Record 21 of Set 9 | shubarkuduk
# Processing Record 22 of Set 9 | bom jesus do galho
# Processing Record 23 of Set 9 | quatre cocos
# Processing Record 24 of Set 9 | kanata
# Processing Record 25 of Set 9 | port lincoln
# Processing Record 26 of Set 9 | faridpur
# Processing Record 27 of Set 9 | ilka
# City not found. Skipping
# Processing Record 28 of Set 9 | evensk
# Processing Record 29 of Set 9 | khonsa
# Processing Record 30 of Set 9 | acapulco
# Processing Record 31 of Set 9 | bereznyky
# Processing Record 32 of Set 9 | nindiri
# Processing Record 33 of Set 9 | springbok
# Processing Record 34 of Set 9 | alekseyevsk
# Processing Record 35 of Set 9 | pascagoula
# Processing Record 36 of Set 9 | gao
# Processing Record 37 of Set 9 | grand river south east
# City not found. Skipping
# Processing Record 38 of Set 9 | weligama
# Processing Record 39 of Set 9 | burns lake
# Processing Record 40 of Set 9 | santa cruz cabralia
# Processing Record 41 of Set 9 | diego de almagro
# Processing Record 42 of Set 9 | teguldet
# Processing Record 43 of Set 9 | ambilobe
# Processing Record 44 of Set 9 | batagay
# Processing Record 45 of Set 9 | baherden
# Processing Record 46 of Set 9 | san cristobal
# Processing Record 47 of Set 9 | krasnoselkup
# Processing Record 48 of Set 9 | arlit
# Processing Record 49 of Set 9 | hua hin
# Processing Record 50 of Set 9 | kununurra
# Processing Record 1 of Set 10 | algiers
# Processing Record 2 of Set 10 | odweyne
# Processing Record 3 of Set 10 | methoni
# Processing Record 4 of Set 10 | te anau
# Processing Record 5 of Set 10 | sur
# Processing Record 6 of Set 10 | walvis bay
# Processing Record 7 of Set 10 | marcona
# City not found. Skipping
# Processing Record 8 of Set 10 | nabire
# Processing Record 9 of Set 10 | somerset east
# Processing Record 10 of Set 10 | moerai
# Processing Record 11 of Set 10 | bubaque
# Processing Record 12 of Set 10 | kyabe
# Processing Record 13 of Set 10 | minatitlan
# Processing Record 14 of Set 10 | rehoboth
# Processing Record 15 of Set 10 | clyde river
# Processing Record 16 of Set 10 | verkh-tula
# Processing Record 17 of Set 10 | arbazh
# Processing Record 18 of Set 10 | ahipara
# Processing Record 19 of Set 10 | lukulu
# Processing Record 20 of Set 10 | vila franca do campo
# Processing Record 21 of Set 10 | tsovazard
# Processing Record 22 of Set 10 | dire dawa
# Processing Record 23 of Set 10 | shadegan
# Processing Record 24 of Set 10 | oume
# Processing Record 25 of Set 10 | solnechnyy
# Processing Record 26 of Set 10 | nouadhibou
# Processing Record 27 of Set 10 | buala
# Processing Record 28 of Set 10 | tanout
# Processing Record 29 of Set 10 | saint-leu
# Processing Record 30 of Set 10 | corinth
# Processing Record 31 of Set 10 | tobermory
# Processing Record 32 of Set 10 | viedma
# Processing Record 33 of Set 10 | sakakah
# Processing Record 34 of Set 10 | hereford
# Processing Record 35 of Set 10 | el bordo
# Processing Record 36 of Set 10 | okha
# Processing Record 37 of Set 10 | monte escobedo
# Processing Record 38 of Set 10 | iqaluit
# Processing Record 39 of Set 10 | bon accord
# Processing Record 40 of Set 10 | lata
# Processing Record 41 of Set 10 | lucapa
# Processing Record 42 of Set 10 | miranorte
# City not found. Skipping
# Processing Record 43 of Set 10 | bahia honda
# Processing Record 44 of Set 10 | montrose
# Processing Record 45 of Set 10 | acarau
# Processing Record 46 of Set 10 | ugoofaaru
# Processing Record 47 of Set 10 | lagoa
# Processing Record 48 of Set 10 | dawei
# Processing Record 49 of Set 10 | ferrol
# Processing Record 50 of Set 10 | fort wellington
# Processing Record 1 of Set 11 | kalmunai
# Processing Record 2 of Set 11 | nanakuli
# Processing Record 3 of Set 11 | flin flon
# Processing Record 4 of Set 11 | jieshi
# Processing Record 5 of Set 11 | tashla
# Processing Record 6 of Set 11 | stony plain
# Processing Record 7 of Set 11 | taltal
# Processing Record 8 of Set 11 | ixtapa
# Processing Record 9 of Set 11 | uglovka
# Processing Record 10 of Set 11 | ust-kamchatsk
# City not found. Skipping
# Processing Record 11 of Set 11 | aksu
# Processing Record 12 of Set 11 | half moon bay
# Processing Record 13 of Set 11 | sebring
# Processing Record 14 of Set 11 | bam
# Processing Record 15 of Set 11 | boa vista
# Processing Record 16 of Set 11 | ola
# Processing Record 17 of Set 11 | suntar
# Processing Record 18 of Set 11 | benin
# Processing Record 19 of Set 11 | kirkwall
# Processing Record 20 of Set 11 | mpraeso
# Processing Record 21 of Set 11 | puerto el triunfo
# Processing Record 22 of Set 11 | quebo
# Processing Record 23 of Set 11 | santona
# Processing Record 24 of Set 11 | mount gambier
# Processing Record 25 of Set 11 | nouakchott
# Processing Record 26 of Set 11 | sinnamary
# Processing Record 27 of Set 11 | dwarka
# Processing Record 28 of Set 11 | bambanglipuro
# Processing Record 29 of Set 11 | fare
# Processing Record 30 of Set 11 | lypova dolyna
# Processing Record 31 of Set 11 | asau
# Processing Record 32 of Set 11 | moose factory
# Processing Record 33 of Set 11 | nuuk
# Processing Record 34 of Set 11 | norilsk
# Processing Record 35 of Set 11 | fallon
# Processing Record 36 of Set 11 | dumas
# Processing Record 37 of Set 11 | port blair
# Processing Record 38 of Set 11 | mahadday weyne
# City not found. Skipping
# Processing Record 39 of Set 11 | gombong
# Processing Record 40 of Set 11 | antofagasta
# Processing Record 41 of Set 11 | gold coast
# Processing Record 42 of Set 11 | pombas
# Processing Record 43 of Set 11 | toucheng
# Processing Record 44 of Set 11 | changde
# Processing Record 45 of Set 11 | grand bend
# Processing Record 46 of Set 11 | kyaukse
# Processing Record 47 of Set 11 | senador jose porfirio
# Processing Record 48 of Set 11 | lazurne
# Processing Record 49 of Set 11 | guerrero negro
# Processing Record 50 of Set 11 | biloela
# Processing Record 1 of Set 12 | baijiantan
# Processing Record 2 of Set 12 | chachapoyas
# Processing Record 3 of Set 12 | guaratuba
# Processing Record 4 of Set 12 | naze
# Processing Record 5 of Set 12 | doljesti
# Processing Record 6 of Set 12 | suozhen
# Processing Record 7 of Set 12 | karratha
# Processing Record 8 of Set 12 | balkhash
# Processing Record 9 of Set 12 | wanning
# Processing Record 10 of Set 12 | cockburn town
# Processing Record 11 of Set 12 | lokosovo
# Processing Record 12 of Set 12 | kiunga
# Processing Record 13 of Set 12 | yukamenskoye
# Processing Record 14 of Set 12 | jedrzejow
# Processing Record 15 of Set 12 | tukan
# Processing Record 16 of Set 12 | tocopilla
# Processing Record 17 of Set 12 | vysokogornyy
# Processing Record 18 of Set 12 | andenes
# Processing Record 19 of Set 12 | novosheshminsk
# Processing Record 20 of Set 12 | itapuranga
# Processing Record 21 of Set 12 | goderich
# Processing Record 22 of Set 12 | erenhot
# Processing Record 23 of Set 12 | jambi
# Processing Record 24 of Set 12 | darhan
# Processing Record 25 of Set 12 | kieta
# Processing Record 26 of Set 12 | saint stephen
# Processing Record 27 of Set 12 | alghero
# Processing Record 28 of Set 12 | beyneu
# Processing Record 29 of Set 12 | lewistown
# Processing Record 30 of Set 12 | broome
# Processing Record 31 of Set 12 | beringovskiy
# Processing Record 32 of Set 12 | deputatskiy
# Processing Record 33 of Set 12 | rio cuarto
# Processing Record 34 of Set 12 | aguimes
# Processing Record 35 of Set 12 | zhaodong
# Processing Record 36 of Set 12 | leshukonskoye
# Processing Record 37 of Set 12 | santiago de cao
# Processing Record 38 of Set 12 | fenoarivo
# Processing Record 39 of Set 12 | lambarene
# Processing Record 40 of Set 12 | monte azul paulista
# Processing Record 41 of Set 12 | chiredzi
# Processing Record 42 of Set 12 | shakhovskaya
# Processing Record 43 of Set 12 | hlukhiv
# Processing Record 44 of Set 12 | gainesville
# Processing Record 45 of Set 12 | magura
# Processing Record 46 of Set 12 | sao jose de piranhas
# Processing Record 47 of Set 12 | kapit
# Processing Record 48 of Set 12 | fortuna
# Processing Record 49 of Set 12 | yangjiang
# Processing Record 50 of Set 12 | kiruna
# Processing Record 1 of Set 13 | puerto asis
# Processing Record 2 of Set 13 | azul
# Processing Record 3 of Set 13 | san patricio
# Processing Record 4 of Set 13 | saryshagan
# City not found. Skipping
# Processing Record 5 of Set 13 | san miguel
# Processing Record 6 of Set 13 | vestmannaeyjar
# Processing Record 7 of Set 13 | malmesbury
# Processing Record 8 of Set 13 | northam
# Processing Record 9 of Set 13 | zlatoust
# Processing Record 10 of Set 13 | esperance
# Processing Record 11 of Set 13 | verkhnyaya inta
# Processing Record 12 of Set 13 | baruun-urt
# Processing Record 13 of Set 13 | touros
# Processing Record 14 of Set 13 | petatlan
# Processing Record 15 of Set 13 | gongzhuling
# Processing Record 16 of Set 13 | havelock
# Processing Record 17 of Set 13 | kungurtug
# Processing Record 18 of Set 13 | neftegorsk
# Processing Record 19 of Set 13 | orlik
# Processing Record 20 of Set 13 | maracacume
# Processing Record 21 of Set 13 | gangotri
# City not found. Skipping
# Processing Record 22 of Set 13 | burma
# Processing Record 23 of Set 13 | big spring
# Processing Record 24 of Set 13 | russell
# Processing Record 25 of Set 13 | nioro
# Processing Record 26 of Set 13 | mantua
# Processing Record 27 of Set 13 | placerville
# Processing Record 28 of Set 13 | port hawkesbury
# Processing Record 29 of Set 13 | pandan
# Processing Record 30 of Set 13 | linguere
# Processing Record 31 of Set 13 | marovoay
# Processing Record 32 of Set 13 | tripoli
# Processing Record 33 of Set 13 | baykalsk
# Processing Record 34 of Set 13 | kumluca
# Processing Record 35 of Set 13 | marsabit
# Processing Record 36 of Set 13 | gramsh
# Processing Record 37 of Set 13 | moscow
# Processing Record 38 of Set 13 | xining
# Processing Record 39 of Set 13 | ende
# Processing Record 40 of Set 13 | akdepe
# Processing Record 41 of Set 13 | oreanda
# City not found. Skipping
# Processing Record 42 of Set 13 | fairbanks
# Processing Record 43 of Set 13 | anadyr
# Processing Record 44 of Set 13 | beni
# Processing Record 45 of Set 13 | vila
# Processing Record 46 of Set 13 | laguna
# Processing Record 47 of Set 13 | koumac
# Processing Record 48 of Set 13 | limoges
# Processing Record 49 of Set 13 | wufeng
# Processing Record 50 of Set 13 | dire
# Processing Record 1 of Set 14 | ndende
# Processing Record 2 of Set 14 | sorvag
# City not found. Skipping
# Processing Record 3 of Set 14 | puerto del rosario
# Processing Record 4 of Set 14 | ushtobe
# Processing Record 5 of Set 14 | katangli
# Processing Record 6 of Set 14 | madang
# Processing Record 7 of Set 14 | wasilla
# Processing Record 8 of Set 14 | shenjiamen
# Processing Record 9 of Set 14 | adrar
# Processing Record 10 of Set 14 | furstenfeldbruck
# City not found. Skipping
# Processing Record 11 of Set 14 | williams lake
# Processing Record 12 of Set 14 | kudahuvadhoo
# Processing Record 13 of Set 14 | phangnga
# Processing Record 14 of Set 14 | griffith
# Processing Record 15 of Set 14 | camacha
# Processing Record 16 of Set 14 | pedasi
# Processing Record 17 of Set 14 | mayo
# Processing Record 18 of Set 14 | san carlos de bariloche
# Processing Record 19 of Set 14 | olopa
# Processing Record 20 of Set 14 | imbituba
# Processing Record 21 of Set 14 | sedelnikovo
# City not found. Skipping
# Processing Record 22 of Set 14 | axim
# Processing Record 23 of Set 14 | gedo
# Processing Record 24 of Set 14 | puerto baquerizo moreno
# Processing Record 25 of Set 14 | nenjiang
# Processing Record 26 of Set 14 | mookane
# Processing Record 27 of Set 14 | paso de los toros
# Processing Record 28 of Set 14 | inverell
# Processing Record 29 of Set 14 | zamosc
# Processing Record 30 of Set 14 | richards bay
# Processing Record 31 of Set 14 | kaeo
# Processing Record 32 of Set 14 | zhigansk
# Processing Record 33 of Set 14 | watsa
# Processing Record 34 of Set 14 | kollumerland
# City not found. Skipping
# Processing Record 35 of Set 14 | tubruq
# City not found. Skipping
# Processing Record 36 of Set 14 | kaliua
# Processing Record 37 of Set 14 | sorland
# Processing Record 38 of Set 14 | meyungs
# City not found. Skipping
# Processing Record 39 of Set 14 | macusani
# Processing Record 40 of Set 14 | ust-tsilma
# Processing Record 41 of Set 14 | portland
# Processing Record 42 of Set 14 | san vicente
# Processing Record 43 of Set 14 | darnah
# Processing Record 44 of Set 14 | las animas
# Processing Record 45 of Set 14 | rudnichnyy
# Processing Record 46 of Set 14 | balikpapan
# Processing Record 47 of Set 14 | onega
# Processing Record 48 of Set 14 | nurota
# Processing Record 49 of Set 14 | tautira
# Processing Record 50 of Set 14 | boras
# Processing Record 1 of Set 15 | henties bay
# Processing Record 2 of Set 15 | luanda
# Processing Record 3 of Set 15 | coquimbo
# Processing Record 4 of Set 15 | comodoro rivadavia
# Processing Record 5 of Set 15 | hofn
# Processing Record 6 of Set 15 | edd
# Processing Record 7 of Set 15 | makung
# City not found. Skipping
# Processing Record 8 of Set 15 | severnyy
# Processing Record 9 of Set 15 | nelson bay
# Processing Record 10 of Set 15 | airai
# Processing Record 11 of Set 15 | tirau
# Processing Record 12 of Set 15 | havoysund
# Processing Record 13 of Set 15 | great falls
# Processing Record 14 of Set 15 | gap
# Processing Record 15 of Set 15 | pogranichnyy
# Processing Record 16 of Set 15 | zhangye
# Processing Record 17 of Set 15 | portsmouth
# Processing Record 18 of Set 15 | kabinda
# Processing Record 19 of Set 15 | armidale
# Processing Record 20 of Set 15 | athabasca
# Processing Record 21 of Set 15 | banda aceh
# Processing Record 22 of Set 15 | saint-pierre
# Processing Record 23 of Set 15 | tukums
# Processing Record 24 of Set 15 | veseloyarsk
# Processing Record 25 of Set 15 | bilma
# Processing Record 26 of Set 15 | honningsvag
# Processing Record 27 of Set 15 | nador
# Processing Record 28 of Set 15 | satipo
# Processing Record 29 of Set 15 | ostersund
# Processing Record 30 of Set 15 | joanopolis
# Processing Record 31 of Set 15 | yamada
# Processing Record 32 of Set 15 | adilcevaz
# Processing Record 33 of Set 15 | berlevag
# Processing Record 34 of Set 15 | ilave
# Processing Record 35 of Set 15 | huntingdon
# Processing Record 36 of Set 15 | samalaeulu
# City not found. Skipping
# Processing Record 37 of Set 15 | kizilskoye
# Processing Record 38 of Set 15 | paamiut
# Processing Record 39 of Set 15 | atambua
# Processing Record 40 of Set 15 | ballina
# Processing Record 41 of Set 15 | mogochin
# City not found. Skipping
# Processing Record 42 of Set 15 | taoudenni
# Processing Record 43 of Set 15 | dublin
# Processing Record 44 of Set 15 | santa maria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0        Katsuura      JP  2022-08-09 01:46:13  35.1333  140.3000     86.02
# 1          Burnie      AU  2022-08-09 01:46:14 -41.0667  145.9167     53.92
# 2         Mersing      MY  2022-08-09 01:46:14   2.4312  103.8405     76.91
# 3          Barrow      US  2022-08-09 01:44:46  71.2906 -156.7887     46.42
# 4       La Orilla      MX  2022-08-09 01:46:14  17.9833 -102.2333     80.20
# 5         Rikitea      PF  2022-08-09 01:46:15 -23.1203 -134.9692     73.72
# 6  Puerto Carreno      CO  2022-08-09 01:46:15   6.1890  -67.4859     77.18
# 7       Caravelas      BR  2022-08-09 01:46:16 -17.7125  -39.2481     73.00
# 8      Nanortalik      GL  2022-08-09 01:46:16  60.1432  -45.2371     41.85
# 9        Kresttsy      RU  2022-08-09 01:46:16  58.2452   32.5165     55.51
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        75          86       21.77     overcast clouds
# 1        68           3        3.29           clear sky
# 2       100          40        4.61    scattered clouds
# 3        61          75       11.50       broken clouds
# 4        77         100        2.53     overcast clouds
# 5        77          99       18.99          light rain
# 6        89          88        2.04     overcast clouds
# 7        74           6        9.46           clear sky
# 8        95           7        7.58           clear sky
# 9        81         100        5.08     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
